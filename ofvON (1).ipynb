# %%
import pandas as pd 
import numpy as np 
# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns
#plt.style.use('seaborn-colorblind')

a=pd.read_excel('shopping.xlsx')

# %% [markdown]
# # Data Cleaning and Transformation

# %%
b=pd.DataFrame(index=np.arange(291), columns=np.arange(15))
b=b.rename(columns={0:'Groceries',1:'Clothing',2:'Electronics',3:'Stationary',4:'Others' , 5: 'Time efficiency',6:'Special offers and discounts',7:'More products at one glance',8: 'Door to door service',9:'Return policies',10:'Privacy',11:'Appearance deceptive',12:'Timely Response',13:'Delivery issues',14:'Misleading quality'})

# %%
a1=a[['Timestamp',"NAME","AGE","GENDER","CITY","NEAREST RAILWAY STATION","EDUCATION","OCCUPATION","MONTHLY FAMILY INCOME","WHICH MODE OF SHOPPING DO YOU PREFER","WITH YOUR INITIAL EXPERIENCE IN BOTH THE MODES OF SHOPPING, WHICH ONE WILL YOU CONTINUE IT IN FUTURE?","HOW HAS COVID-19 AFFECTED YOUR SHOPPING BEHAVIOR ?" ,"AVG AGE","AVG MONTHLY FAMILY INCOME"]]

# %%
g1 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [1]'] == 'Grocery'].index
e1 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [1]'] == 'Electronic'].index
c1 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [1]'] == 'Clothing'].index
s1 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [1]'] == 'Stationary'].index
o1 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [1]'] == 'Others'].index

g2 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [2]'] == 'Grocery'].index
e2 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [2]'] == 'Electronic'].index
c2 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [2]'] == 'Clothing'].index
s2 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [2]'] == 'Stationary'].index
o2 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [2]'] == 'Others'].index

g3 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [3]'] == 'Grocery'].index
e3 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [3]'] == 'Electronic'].index
c3 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [3]'] == 'Clothing'].index
s3 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [3]'] == 'Stationary'].index
o3 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [3]'] == 'Others'].index

g4 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [4]'] == 'Grocery'].index
e4 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [4]'] == 'Electronic'].index
c4 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [4]'] == 'Clothing'].index
s4 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [4]'] == 'Stationary'].index
o4 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [4]'] == 'Others'].index

g5 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [5]'] == 'Grocery'].index
e5 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [5]'] == 'Electronic'].index
c5 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [5]'] == 'Clothing'].index
s5 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [5]'] == 'Stationary'].index
o5 = a[a['AS PER PREFERENCES RANK STARS ACCORDINGLY FOR ONLINE SHOPPING [5]'] == 'Others'].index

# %%
for i in g1:
    b['Groceries'][i]=1
for i in e1:
    b['Electronics'][i]=1
for i in c1:
    b['Clothing'][i]=1
for i in s1:
    b['Stationary'][i]=1
for i in o1:
    b['Others'][i]=1
    
for i in g2:
    b['Groceries'][i]=2
for i in e2:
    b['Electronics'][i]=2
for i in c2:
    b['Clothing'][i]=2
for i in s2:
    b['Stationary'][i]=2
for i in o2:
    b['Others'][i]=2

for i in g3:
    b['Groceries'][i]=3
for i in e3:
    b['Electronics'][i]=3
for i in c3:
    b['Clothing'][i]=3
for i in s3:
    b['Stationary'][i]=3
for i in o3:
    b['Others'][i]=3
    
for i in g4:
    b['Groceries'][i]=4
for i in e4:
    b['Electronics'][i]=4
for i in c4:
    b['Clothing'][i]=4
for i in s4:
    b['Stationary'][i]=4
for i in o4:
    b['Others'][i]=4
    
for i in g5:
    b['Groceries'][i]=5
for i in e5:
    b['Electronics'][i]=5
for i in c5:
    b['Clothing'][i]=5
for i in s5:
    b['Stationary'][i]=5
for i in o5:
    b['Others'][i]=5

# %%
g1 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [1]'] == 'Special offers and discounts'].index
e1 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [1]'] == 'Time efficiency'].index
c1 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [1]'] == 'Door to door service'].index
s1 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [1]'] == 'More products at one glance'].index
o1 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [1]'] == 'Return policies'].index

g2 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [2]'] == 'Special offers and discounts'].index
e2 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [2]'] == 'Time efficiency'].index
c2 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [2]'] == 'Door to door service'].index
s2 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [2]'] == 'More products at one glance'].index
o2 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [2]'] == 'Return policies'].index

g3 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [3]'] == 'Special offers and discounts'].index
e3 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [3]'] == 'Time efficiency'].index
c3 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [3]'] == 'Door to door service'].index
s3 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [3]'] == 'More products at one glance'].index
o3 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [3]'] == 'Return policies'].index

g4 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [4]'] == 'Special offers and discounts'].index
e4 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [4]'] == 'Time efficiency'].index
c4 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [4]'] == 'Door to door service'].index
s4 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [4]'] == 'More products at one glance'].index
o4 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [4]'] == 'Return policies'].index

g5 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [5]'] == 'Special offers and discounts'].index
e5 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [5]'] == 'Time efficiency'].index
c5 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [5]'] == 'Door to door service'].index
s5 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [5]'] == 'More products at one glance'].index
o5 = a[a['WHY WOULD YOU CHOOSE ONLINE SHOPPING (RANK STARS ACCORDING TO PREFERENCES) [5]'] == 'Return policies'].index

# %%
for i in g1:
    b['Special offers and discounts'][i]=1
for i in e1:
    b['Time efficiency'][i]=1
for i in c1:
    b['Door to door service'][i]=1
for i in s1:
    b['More products at one glance'][i]=1
for i in o1:
    b['Return policies'][i]=1
    
for i in g2:
    b['Special offers and discounts'][i]=2
for i in e2:
    b['Time efficiency'][i]=2
for i in c2:
    b['Door to door service'][i]=2
for i in s2:
    b['More products at one glance'][i]=2
for i in o2:
    b['Return policies'][i]=2

for i in g3:
    b['Special offers and discounts'][i]=3
for i in e3:
    b['Time efficiency'][i]=3
for i in c3:
    b['Door to door service'][i]=3
for i in s3:
    b['More products at one glance'][i]=3
for i in o3:
    b['Return policies'][i]=3
    
for i in g4:
    b['Special offers and discounts'][i]=4
for i in e4:
    b['Time efficiency'][i]=4
for i in c4:
    b['Door to door service'][i]=4
for i in s4:
    b['More products at one glance'][i]=4
for i in o4:
    b['Return policies'][i]=4
    
for i in g5:
    b['Special offers and discounts'][i]=5
for i in e5:
    b['Time efficiency'][i]=5
for i in c5:
    b['Door to door service'][i]=5
for i in s5:
    b['More products at one glance'][i]=5
for i in o5:
    b['Return policies'][i]=5

# %%
g1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [1]'] == 'Privacy'].index
e1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [1]'] == 'Appearance deceptive'].index
c1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [1]'] == 'Timely Response'].index
s1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [1]'] == 'Delivery issues'].index
o1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [1]'] == 'Misleading quality'].index

g2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [2]'] == 'Privacy'].index
e2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [2]'] == 'Appearance deceptive'].index
c2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [2]'] == 'Timely Response'].index
s2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [2]'] == 'Delivery issues'].index
o2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [2]'] == 'Misleading quality'].index

g3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [3]'] == 'Privacy'].index
e3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [3]'] == 'Appearance deceptive'].index
c3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [3]'] == 'Timely Response'].index
s3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [3]'] == 'Delivery issues'].index
o3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [3]'] == 'Misleading quality'].index

g4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [4]'] == 'Privacy'].index
e4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [4]'] == 'Appearance deceptive'].index
c4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [4]'] == 'Timely Response'].index
s4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [4]'] == 'Delivery issues'].index
o4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [4]'] == 'Misleading quality'].index

g5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [5]'] == 'Privacy'].index
e5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [5]'] == 'Appearance deceptive'].index
c5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [5]'] == 'Timely Response'].index
s5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [5]'] == 'Delivery issues'].index
o5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [5]'] == 'Misleading quality'].index

# %%
for i in g1:
    b['Privacy'][i]=1
for i in e1:
    b['Appearance deceptive'][i]=1
for i in c1:
    b['Timely Response'][i]=1
for i in s1:
    b['Delivery issues'][i]=1
for i in o1:
    b['Misleading quality'][i]=1
    
for i in g2:
    b['Privacy'][i]=2
for i in e2:
    b['Appearance deceptive'][i]=2
for i in c2:
    b['Timely Response'][i]=2
for i in s2:
    b['Delivery issues'][i]=2
for i in o2:
    b['Misleading quality'][i]=2

for i in g3:
    b['Privacy'][i]=3
for i in e3:
    b['Appearance deceptive'][i]=3
for i in c3:
    b['Timely Response'][i]=3
for i in s3:
    b['Delivery issues'][i]=3
for i in o3:
    b['Misleading quality'][i]=3
    
for i in g4:
    b['Privacy'][i]=4
for i in e4:
    b['Appearance deceptive'][i]=4
for i in c4:
    b['Timely Response'][i]=4
for i in s4:
    b['Delivery issues'][i]=4
for i in o4:
    b['Misleading quality'][i]=4
    
for i in g5:
    b['Privacy'][i]=5
for i in e5:
    b['Appearance deceptive'][i]=5
for i in c5:
    b['Timely Response'][i]=5
for i in s5:
    b['Delivery issues'][i]=5
for i in o5:
    b['Misleading quality'][i]=5

# %%
c=pd.DataFrame(index=np.arange(291), columns=np.arange(15))
c=c.rename(columns={0:'Groceries-of',1:'Clothing-of',2:'Electronics-of',3:'Stationary-of',4:'Others-of' , 5: 'Lesser use of technology',6:'Like to suspect before buying',7:'Bargaining',8: 'On spot delivery',9:'Window shopping',10:'Unwanted Travelling',11:'Unwanted queue',12:'Compulsive shopkeeper',13:'No review analysis',14:'No satisfactory discounts'})

# %%
g1 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [1]'] == 'Grocery'].index
e1 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [1]'] == 'Electronics'].index
c1 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [1]'] == 'Clothing'].index
s1 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [1]'] == 'Stationary'].index
o1 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [1]'] == 'Others'].index

g2 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [2]'] == 'Grocery'].index
e2 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [2]'] == 'Electronics'].index
c2 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [2]'] == 'Clothing'].index
s2 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [2]'] == 'Stationary'].index
o2 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [2]'] == 'Others'].index

g3 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [3]'] == 'Grocery'].index
e3 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [3]'] == 'Electronics'].index
c3 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [3]'] == 'Clothing'].index
s3 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [3]'] == 'Stationary'].index
o3 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [3]'] == 'Others'].index


g4 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [4]'] == 'Grocery'].index
e4 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [4]'] == 'Electronics'].index
c4 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [4]'] == 'Clothing'].index
s4 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [4]'] == 'Stationary'].index
o4 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [4]'] == 'Others'].index

g5 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [5]'] == 'Grocery'].index
e5 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [5]'] == 'Electronics'].index
c5 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [5]'] == 'Clothing'].index
s5 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [5]'] == 'Stationary'].index
o5 = a[a['RANK STARS AS PER PREFERENCES FOR OFFLINE SHOPPING FROM GIVEN LIST: [5]'] == 'Others'].index

# %%
for i in g1:
    c['Groceries-of'][i]=1
for i in e1:
    c['Electronics-of'][i]=1
for i in c1:
    c['Clothing-of'][i]=1
for i in s1:
    c['Stationary-of'][i]=1
for i in o1:
    c['Others-of'][i]=1
    
for i in g2:
    c['Groceries-of'][i]=2
for i in e2:
    c['Electronics-of'][i]=2
for i in c2:
    c['Clothing-of'][i]=2
for i in s2:
    c['Stationary-of'][i]=2
for i in o2:
    c['Others-of'][i]=2

for i in g3:
    c['Groceries-of'][i]=3
for i in e3:
    c['Electronics-of'][i]=3
for i in c3:
    c['Clothing-of'][i]=3
for i in s3:
    c['Stationary-of'][i]=3
for i in o3:
    c['Others-of'][i]=3
    
for i in g4:
    c['Groceries-of'][i]=4
for i in e4:
    c['Electronics-of'][i]=4
for i in c4:
    c['Clothing-of'][i]=4
for i in s4:
    c['Stationary-of'][i]=4
for i in o4:
    c['Others-of'][i]=4
    
for i in g5:
    c['Groceries-of'][i]=5
for i in e5:
    c['Electronics-of'][i]=5
for i in c5:
    c['Clothing-of'][i]=5
for i in s5:
    c['Stationary-of'][i]=5
for i in o5:
    c['Others-of'][i]=5

# %%
g1 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [1]'] == 'Like to suspect before buying'].index
e1 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [1]'] == 'Lesser use of technology'].index
c1 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [1]'] == 'Bargaining'].index
s1 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [1]'] == 'On spot delivery'].index
o1 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [1]'] == 'Window shopping'].index

g2 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [2]'] == 'Like to suspect before buying'].index
e2 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [2]'] == 'Lesser use of technology'].index
c2 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [2]'] == 'Bargaining'].index
s2 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [2]'] == 'On spot delivery'].index
o2 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [2]'] == 'Window shopping'].index

g3 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [3]'] == 'Like to suspect before buying'].index
e3 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [3]'] == 'Lesser use of technology'].index
c3 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [3]'] == 'Bargaining'].index
s3 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [3]'] == 'On spot delivery'].index
o3 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [3]'] == 'Window shopping'].index

g4 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [4]'] == 'Like to suspect before buying'].index
e4 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [4]'] == 'Lesser use of technology'].index
c4 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [4]'] == 'Bargaining'].index
s4 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [4]'] == 'On spot delivery'].index
o4 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [4]'] == 'Window shopping'].index

g5 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [5]'] == 'Like to suspect before buying'].index
e5 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [5]'] == 'Lesser use of technology'].index
c5 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [5]'] == 'Bargaining'].index
s5 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [5]'] == 'On spot delivery'].index
o5 = a[a['WHY WOULD YOU CHOOSE OFFLINE SHOPPING ?(RANK STARS AS PER PREFERENCES) [5]'] == 'Window shopping'].index

# %%
for i in g1:
    c['Lesser use of technology'][i]=1
for i in e1:
    c['Like to suspect before buying'][i]=1
for i in c1:
    c['Bargaining'][i]=1
for i in s1:
    c['On spot delivery'][i]=1
for i in o1:
    c['Window shopping'][i]=1
    
for i in g2:
    c['Lesser use of technology'][i]=2
for i in e2:
    c['Like to suspect before buying'][i]=2
for i in c2:
    c['Bargaining'][i]=2
for i in s2:
    c['On spot delivery'][i]=2
for i in o2:
    c['Window shopping'][i]=2

for i in g3:
    c['Lesser use of technology'][i]=3
for i in e3:
    c['Like to suspect before buying'][i]=3
for i in c3:
    c['Bargaining'][i]=3
for i in s3:
    c['On spot delivery'][i]=3
for i in o3:
    c['Window shopping'][i]=3
    
for i in g4:
    c['Lesser use of technology'][i]=4
for i in e4:
    c['Like to suspect before buying'][i]=4
for i in c4:
    c['Bargaining'][i]=4
for i in s4:
    c['On spot delivery'][i]=4
for i in o4:
    c['Window shopping'][i]=4
    
for i in g5:
    c['Lesser use of technology'][i]=5
for i in e5:
    c['Like to suspect before buying'][i]=5
for i in c5:
    c['Bargaining'][i]=5
for i in s5:
    c['On spot delivery'][i]=5
for i in o5:
    c['Window shopping'][i]=5

# %%
g1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [1]'] == 'Unwanted Travelling'].index
e1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [1]'] == 'Unwanted queue'].index
c1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [1]'] == 'No satisfactory discounts'].index
s1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING ONLINE? (RANK STARS AS PER PREFERENCES) [1]'] == 'No review analysis'].index
o1 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [1]'] == 'Compulsive shopkeeper'].index

g2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [2]'] == 'Unwanted Travelling'].index
e2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [2]'] == 'Unwanted queue'].index
c2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [2]'] == 'No satisfactory discounts'].index
s2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [2]'] == 'No review analysis'].index
o2 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [2]'] == 'Compulsive shopkeeper'].index

g3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [3]'] == 'Unwanted Travelling'].index
e3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [3]'] == 'Unwanted queue'].index
c3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [3]'] == 'No satisfactory discounts'].index
s3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [3]'] == 'No review analysis'].index
o3 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [3]'] == 'Compulsive shopkeeper'].index

g4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [4]'] == 'Unwanted Travelling'].index
e4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [4]'] == 'Unwanted queue'].index
c4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [4]'] == 'No satisfactory discounts'].index
s4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [4]'] == 'No review analysis'].index
o4 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [4]'] == 'Compulsive shopkeeper'].index

g5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [5]'] == 'Unwanted Travelling'].index
e5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [5]'] == 'Unwanted queue'].index
c5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [5]'] == 'No satisfactory discounts'].index
s5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [5]'] == 'No review analysis'].index
o5 = a[a['WHAT ARE YOUR BIGGEST CONCERN BUYING OFFLINE ? (RANK STARS AS PER PREFERENCES) [5]'] == 'Compulsive shopkeeper'].index

# %%
for i in g1:
    c['Unwanted Travelling'][i]=1
for i in e1:
    c['Unwanted queue'][i]=1
for i in c1:
    c['Compulsive shopkeeper'][i]=1
for i in s1:
    c['No review analysis'][i]=1
for i in o1:
    c['No satisfactory discounts'][i]=1
    
for i in g2:
    c['Unwanted Travelling'][i]=2
for i in e2:
    c['Unwanted queue'][i]=2
for i in c2:
    c['Compulsive shopkeeper'][i]=2
for i in s2:
    c['No review analysis'][i]=2
for i in o2:
    c['No satisfactory discounts'][i]=2

for i in g3:
    c['Unwanted Travelling'][i]=3
for i in e3:
    c['Unwanted queue'][i]=3
for i in c3:
    c['Compulsive shopkeeper'][i]=3
for i in s3:
    c['No review analysis'][i]=3
for i in o3:
    c['No satisfactory discounts'][i]=3
    
for i in g4:
    c['Unwanted Travelling'][i]=4
for i in e4:
    c['Unwanted queue'][i]=4
for i in c4:
    c['Compulsive shopkeeper'][i]=4
for i in s4:
    c['No review analysis'][i]=4
for i in o4:
    c['No satisfactory discounts'][i]=4
    
for i in g5:
    c['Unwanted Travelling'][i]=5
for i in e5:
    c['Unwanted queue'][i]=5
for i in c5:
    c['Compulsive shopkeeper'][i]=5
for i in s5:
    c['No review analysis'][i]=5
for i in o5:
    c['No satisfactory discounts'][i]=5

# %%
x = a[["APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR GROCERY ? (IN RUPEES)", "APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR CLOTHING ? (IN RUPEES)","AVERAGE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR ELECTRONIC ? (IN RUPEES)","APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR STATIONARY ? (IN RUPEES)"]]
online = b.merge(x, how='outer', right_index=True, left_index=True)
online=a1.merge(online, how='outer', right_index=True, left_index=True)
online
# Out:
#                            Timestamp                  NAME       AGE  GENDER  \
# 0    2020/10/14 11:50:40 PM GMT+5:30        Rishabh Kokane     18-25    Male
# 1    2020/10/14 11:52:20 PM GMT+5:30            Yash Salvi  Below 18    Male
# 2    2020/10/14 11:52:32 PM GMT+5:30     Hamsika Kondamudi     18-25  Female
# 3    2020/10/14 11:56:08 PM GMT+5:30          Viraj Jadhav     18-25    Male
# 4    2020/10/14 11:57:22 PM GMT+5:30           Sejal Dubey     18-25  Female
# 5    2020/10/14 11:59:01 PM GMT+5:30        Hrutuja Patkar     18-25  Female
# 6    2020/10/15 12:00:04 AM GMT+5:30         Shruti Patkar     18-25  Female
# 7    2020/10/15 12:00:37 AM GMT+5:30         Sharvari Bote     18-25  Female
# 8    2020/10/15 12:07:13 AM GMT+5:30         Rucha Kenjale     18-25  Female
# 9    2020/10/15 12:08:34 AM GMT+5:30     Siddhesh Deshmukh     18-25    Male
# 10   2020/10/15 12:12:34 AM GMT+5:30               Apeksha     18-25  Female
# ...

# %%
y = a[["APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR GROCERY? (IN RUPEES)", "APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR CLOTHING? (IN RUPEES)","APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR ELECTRONIC ? (IN RUPEES)","APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR STATIONARY? (IN RUPEES)"]]
offline = c.merge(y, how='outer', right_index=True, left_index=True)
offline=a1.merge(offline, how='outer', right_index=True, left_index=True)
offline
# Out:
#                            Timestamp                  NAME       AGE  GENDER  \
# 0    2020/10/14 11:50:40 PM GMT+5:30        Rishabh Kokane     18-25    Male
# 1    2020/10/14 11:52:20 PM GMT+5:30            Yash Salvi  Below 18    Male
# 2    2020/10/14 11:52:32 PM GMT+5:30     Hamsika Kondamudi     18-25  Female
# 3    2020/10/14 11:56:08 PM GMT+5:30          Viraj Jadhav     18-25    Male
# 4    2020/10/14 11:57:22 PM GMT+5:30           Sejal Dubey     18-25  Female
# 5    2020/10/14 11:59:01 PM GMT+5:30        Hrutuja Patkar     18-25  Female
# 6    2020/10/15 12:00:04 AM GMT+5:30         Shruti Patkar     18-25  Female
# 7    2020/10/15 12:00:37 AM GMT+5:30         Sharvari Bote     18-25  Female
# 8    2020/10/15 12:07:13 AM GMT+5:30         Rucha Kenjale     18-25  Female
# 9    2020/10/15 12:08:34 AM GMT+5:30     Siddhesh Deshmukh     18-25    Male
# 10   2020/10/15 12:12:34 AM GMT+5:30               Apeksha     18-25  Female
# ...

# %%
ob_mean=online[["Special offers and discounts","Time efficiency","Door to door service","More products at one glance","Return policies"]].mean()
ob_mean
ob_mean1=pd.DataFrame([ob_mean])
ob_mean1=ob_mean1.T
ob_mean1["values"]=ob_mean1[0]
ob_mean1["name"]=ob_mean1.index

# %%
od_mean=online[["Privacy","Appearance deceptive","Timely Response","Delivery issues","Misleading quality"]].mean()
od_mean
od_mean1=pd.DataFrame([od_mean])
od_mean1=od_mean1.T
od_mean1["values"]=od_mean1[0]
od_mean1["name"]=od_mean1.index

# %%
ofb_mean=offline[["Lesser use of technology","Like to suspect before buying","Bargaining","On spot delivery","Window shopping"]].mean()
ofb_mean
ofb_mean1=pd.DataFrame([ofb_mean])
ofb_mean1=ofb_mean1.T
ofb_mean1["values"]=ofb_mean1[0]
ofb_mean1["name"]=ofb_mean1.index

# %% [markdown]
# # Data Visualisation

# %%
ofd_mean=offline[["Unwanted Travelling","Unwanted queue","Compulsive shopkeeper","No review analysis","No satisfactory discounts"]].mean()
ofd_mean
ofd_mean1=pd.DataFrame([ofd_mean])
ofd_mean1=ofd_mean1.T
ofd_mean1["values"]=ofd_mean1[0]
ofd_mean1["name"]=ofd_mean1.index
ofd_mean1

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, figsize=(12,8) )
ob_mean1["values"].plot(kind='barh', x='name',  legend=False, ax=ax1,color='green',alpha=0.3)
ax1.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='off')
for i, v,w in zip(ob_mean1["values"],[0,1,2,3,4],ob_mean1["name"]):
    ax1.text(0, v-0.1, str(w)+" = "+str(round(i,2)), color='black', fontweight='bold')
od_mean1["values"].plot(kind='barh', x='name',  legend=False, ax=ax2,color='red',alpha=0.3)
ax2.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='off')
for i, v,w in zip(od_mean1["values"],[0,1,2,3,4],od_mean1["name"]):
    ax2.text(0, v-0.1, str(w)+" = "+str(round(i,2)), color='black', fontweight='bold')
ofb_mean1["values"].plot(kind='barh', x='name',  legend=False, ax=ax3,color='green',alpha=0.3)
ax3.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='off')
for i, v,w in zip(ofb_mean1["values"],[0,1,2,3,4],ofb_mean1["name"]):
    ax3.text(0, v-0.1, str(w)+" = "+str(round(i,2)), color='black', fontweight='bold')
ofd_mean1["values"].plot(kind='barh', x='name',  legend=False, ax=ax4,color='red',alpha=0.3)
ax4.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='off')
for i, v,w in zip(ofd_mean1["values"],[0,1,2,3,4],ofd_mean1["name"]):
    ax4.text(0, v-0.1, str(w)+" = "+str(round(i,2)), color='black', fontweight='bold')
ax1.title.set_text('Benefits Of Online Shopping')
ax2.title.set_text('Drawbacks Of Online Shopping')
ax3.title.set_text('Benefits  Of Offline Shopping')
ax4.title.set_text('Drawbacks Of Offline Shopping')    
fig.suptitle('BENEFITS AND DRAWBACKS OF ONLINE AND OFFLINE SHOPPING' , fontweight = 'bold') 
plt.savefig("BD.png")


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
on_mean=online[["Groceries","Electronics","Clothing","Stationary","Others"]].mean()
on_mean
on_mean1=pd.DataFrame([on_mean])
on_mean1=on_mean1.T
on_mean1["values"]=on_mean1[0]
on_mean1["name"]=on_mean1.index

# %%
of_mean=offline[["Groceries-of","Electronics-of","Clothing-of","Stationary-of","Others-of"]].mean()
of_mean
of_mean1=pd.DataFrame([of_mean])
of_mean1=of_mean1.T
of_mean1["values"]=of_mean1[0]
of_mean1["name"]=of_mean1.index

# %%
plt.figure()
n_groups = 5

index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.6

rects1 = plt.bar(index, on_mean1["values"], bar_width,alpha=opacity,color='b',label='Online')

rects2 = plt.bar(index + bar_width, of_mean1["values"], bar_width,alpha=opacity,color='r',label='Offline')

plt.xlabel('Different Shopping Sections', fontweight = "bold")
plt.ylabel('Star Ratings', fontweight = "bold")
plt.title('PEOPLE\'S PREFERENCE FOR GOODS IN BOTH MODES OF SHOPPING ' , fontweight = "bold")
plt.xticks(index + bar_width, ('Groceries',"Electronics", 'Clothing', "Stationary","Others"))
plt.legend()

plt.tight_layout()
plt.show()
plt.savefig("figure.png")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Covariance

# %%
online.replace("-" ,0, inplace=True)
online.replace("." ,0, inplace=True)
online["TOTAL"]= online["APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR GROCERY ? (IN RUPEES)"].astype(float)+ online["APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR CLOTHING ? (IN RUPEES)"].astype(float)+online["APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR STATIONARY ? (IN RUPEES)"].astype(float)+online["AVERAGE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR ELECTRONIC ? (IN RUPEES)"].astype(float)

from scipy.stats import pearsonr
from scipy.stats import spearmanr
from numpy import cov

corr= cov(a1["AVG AGE"].astype(float),online["TOTAL"].astype(float))
print(corr)
corr1,_ = pearsonr(a1["AVG AGE"].astype(float),online["TOTAL"].astype(float))
print(corr1)
corr2, _ = spearmanr(a1["AVG AGE"].astype(float),online["TOTAL"].astype(float))
print(corr2)
# Out:
# [[  8.08532528e+01  -9.06243157e+02]
#  [ -9.06243157e+02   1.35932232e+08]]
# -0.00864439827449
# 0.0192525117652

# %%
offline.replace("-" ,0, inplace=True)
offline.replace("." ,0, inplace=True)
corr = cov(a1["AVG MONTHLY FAMILY INCOME"].astype(float),online["TOTAL"].astype(float))
print(corr)
corr1,_ = pearsonr(a1["AVG MONTHLY FAMILY INCOME"].astype(float),online["TOTAL"].astype(float))
print(corr1)
corr2, _ = spearmanr(a1["AVG MONTHLY FAMILY INCOME"].astype(float),online["TOTAL"].astype(float))
print(corr2)
# Out:
# [[  1.85955534e+08   9.74209829e+06]
#  [  9.74209829e+06   1.35932232e+08]]
# 0.0612754810819
# 0.0898225524918

# %%
plt.figure(figsize=(9,9))
df2 = pd.DataFrame(data = offline , columns = ['APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR GROCERY? (IN RUPEES)','APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR CLOTHING? (IN RUPEES)','APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR ELECTRONIC ? (IN RUPEES)','APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR STATIONARY? (IN RUPEES)'])
df2.rename(columns = {'APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR GROCERY? (IN RUPEES)':'Grocery',  
                       'APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR CLOTHING? (IN RUPEES)':'Clothing' ,
                     'APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR ELECTRONIC ? (IN RUPEES)': 'Electronic',
                    'APPROXIMATE MONEY SPENT MONTHLY ON OFFLINE SHOPPING FOR STATIONARY? (IN RUPEES)' : 'Stationary'}, inplace = True)
ax = sns.boxplot(data=df2, palette="Set1", linewidth=2.5 , showmeans= True ,  meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set(ylim=(-1000, 12500))
sns.axes_style("whitegrid")
ax = ax.axes
lines = ax.get_lines()
categories = ax.get_xticks()

plt.xlabel("Sections of Offline Shopping", fontweight = "bold")
plt.ylabel("Monthly Expenditure", fontweight = "bold")
plt.title('PEOPLE\'S PREFERENCE FOR GOODS FOR OFFLINE SHOPPING ' , fontweight = "bold")

ax.figure.tight_layout()
plt.savefig("OFFLINEBOXPLOT.png")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
plt.figure(figsize=(8,6))
df = pd.DataFrame(data = online, columns = ['APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR GROCERY ? (IN RUPEES)','APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR CLOTHING ? (IN RUPEES)','AVERAGE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR ELECTRONIC ? (IN RUPEES)','APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR STATIONARY ? (IN RUPEES)'])
df.rename(columns = {'APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR GROCERY ? (IN RUPEES)':'Grocery',  
                       'APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR CLOTHING ? (IN RUPEES)':'Clothing' ,
                     'AVERAGE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR ELECTRONIC ? (IN RUPEES)': 'Electronic',
                    'APPROXIMATE MONEY SPENT MONTHLY ON ONLINE SHOPPING FOR STATIONARY ? (IN RUPEES)' : 'Stationary'}, inplace = True)

ax = sns.boxplot(data=df, palette="Set1", linewidth=2.5 , showmeans = True,  meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"}, whis=1.5)
ax.set(ylim=(-500, 8000))
sns.axes_style("whitegrid")
ax = ax.axes
lines = ax.get_lines()



plt.xlabel("Sections of Online Shopping")
plt.ylabel("Monthly Expenditure")
plt.title('MONTHLY EXPENDITURE FOR'  , fontweight = "bold")

ax.figure.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">
